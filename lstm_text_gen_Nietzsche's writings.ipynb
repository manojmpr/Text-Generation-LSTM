# %% [markdown]
# # Long Short-term Memory for Text Generation

# %% [markdown]
# This notebook uses LSTM neural network to generate text from Nietzsche's writings.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import random
import sys
import io


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.utils import get_file

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Get the data
# Nietzsche's writing dataset is available online. The following code download the dataset.

# %%
path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 [==============================] - 5s 9us/step

# %% [markdown]
# ### Visualize data

# %%
print('corpus length:', len(text))
# Out:
# corpus length: 600893

# %%
print(text[10:513])
# Out:
# supposing that truth is a woman--what then? is there not ground
# for suspecting that all philosophers, in so far as they have been
# dogmatists, have failed to understand women--that the terrible
# seriousness and clumsy importunity with which they have usually paid
# their addresses to truth, have been unskilled and unseemly methods for
# winning a woman? certainly she has never allowed herself to be won; and
# at present every kind of dogma stands with sad and discouraged mien--if,
# indeed, it stands at all!

# %%
chars = sorted(list(set(text)))
# total nomber of characters
print('total chars:', len(chars))
# Out:
# total chars: 57

# %% [markdown]
# ### Clean data
#
# We cut the text in sequences of maxlen characters with a jump size of 3.
# The features for each example is a matrix of size maxlen*num of chars.
# The label for each example is a vector of size num of chars, which represents the next character.

# %%
# create (character, index) and (index, character) dictionary
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200285

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...
# <ipython-input-8-b1fdc504c468>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# <ipython-input-8-b1fdc504c468>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %% [markdown]
# ## The model

# %% [markdown]
# ### Build the model - fill in this box

# %% [markdown]
# ## 1. Model 1

# %% [markdown]
# we need a recurrent layer with input shape (maxlen, len(chars)) and a dense layer with output size  len(chars)

# %%
# Build the model
model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(128, input_shape=(maxlen, len(chars))),
    tf.keras.layers.Dense(len(chars), activation='softmax')
])
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

# %% [markdown]
# ### Inspect the model
#
# Use the `.summary` method to print a simple description of the model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               95232
#
#  dense (Dense)               (None, 57)                7353
#
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
class PrintLoss(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, _):
        # Function invoked at end of each epoch. Prints generated text.
        print()
        print('----- Generating text after Epoch: %d' % epoch)

        start_index = random.randint(0, len(text) - maxlen - 1)
        for diversity in [0.5, 1.0]:
            print('----- diversity:', diversity)

            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            sys.stdout.write(generated)

            for i in range(400):
                x_pred = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x_pred[0, t, char_indices[char]] = 1.

                preds = model.predict(x_pred, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()

# %%
EPOCHS = 60
BATCH = 128

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)

history = model.fit(x, y,
                    batch_size = BATCH,
                    epochs = EPOCHS,
                    validation_split = 0.2,
                    verbose = 1,
                    callbacks = [early_stop, PrintLoss()])
# Out:
# Epoch 1/60
# 1247/1252 [============================>.] - ETA: 0s - loss: 2.6428
# ----- Generating text after Epoch: 0
# ----- diversity: 0.5
# ----- Generating with seed: "--the greeks, for
# instance, were a natio"
# --the greeks, for
# instance, were a natiot hhe the sons whit an the the ther andertithe tor
# ftor wire be the whe hore he wore pererand of the matres fhat of whers the frarit to the thit be the med we there the wimo the the for whe to the ang as wall fhan the the the bhas win he sang and remenesons and sore the the asd ofre dere be cor mere the soun the the remong and thit theis be the mone longtithe sor inmesby fpered and bere and the in
# ----- diversity: 1.0
# ----- Generating with seed: "--the greeks, for
# instance, were a natio"
# --the greeks, for
# instance, were a natiols, da re9atwis tpecy ociphi dosikg iope taeli! limand weds. ho ckere tooverhoe ace h pnde none"s ly érifslty entiws be ale of mhe rorerod"
# s, mosl
# orese toy an me fgre hare bh puinhelb rebsondygang the. tiny mp sotell -fmemgen the farl prof be greandiss bpese fosptutfrrpern ant, wur incer, ot ind mpast he cy ind opd]iony aw ofreor lnyseat mlsutr, narcing many muretinnz
# in re
# th the rers onnporily
# 1252/1252 [==============================] - 59s 42ms/step - loss: 2.6423 - val_loss: 2.3725
# Epoch 2/60
# 1252/1252 [==============================] - ETA: 0s - loss: 2.3084
# ----- Generating text after Epoch: 1
# ----- diversity: 0.5
# ----- Generating with seed: " could have been no life at all except u"
#  could have been no life at all except us ave the ass the forte the whit for of al por han mersencor of the the derists and stullity thal the s sis co che seprent an semsouns in the whor sonter at and als as bed sore co stith whis al dallo it of mand call the that or the serensty and the sors as pereatith no seing and and the lowe has and the whin hing and what ex and and apcerent in the sere, the mand sol the shis tho he for dibno and
# ----- diversity: 1.0
# ----- Generating with seed: " could have been no life at all except u"
#  could have been no life at all except ur. are suan "nost (or whe qhe hpreghart thiod diop this ally spsofly andd nase
# an erely ianc
# ther nodevs busl be of chapl th simon
# de foas and thir ons rophe r2intre fur tuyll, anctho thy fornn, an als ande dat daver--b sh
# ofs. endeme hand pheamart, to sseky for ans
# are
# sofl_odl the pr.oce, les fall',
# meven. in moot ot at perialy gurd "ond erow wist bpebenas th stow the ferletity a the whino hithc
# 1252/1252 [==============================] - 51s 41ms/step - loss: 2.3084 - val_loss: 2.2275
# Epoch 3/60
# 1246/1252 [============================>.] - ETA: 0s - loss: 2.1895
# ----- Generating text after Epoch: 2
# ----- diversity: 0.5
# ----- Generating with seed: "self until finally he utters
# falsehood a"
# self until finally he utters
# falsehood and is nat of the oneruens and peringe the latere the hepead of of of the s and in of the the mast on the ware soment and inded aly a the serens derting the becimation on the siching the stele as tue the comither and and and the sourengen in on the erpalion of the meat of the hat ale prorects
# of
# wimpes, an and in the fundeand and in the sepirit and peatity and as and on the seund the meat of the an
# ----- diversity: 1.0
# ----- Generating with seed: "self until finally he utters
# falsehood a"
# self until finally he utters
# falsehood ans penomiopttaisusexsanepencuth fers aksintt ob
# roun and ingiconally stmict and bein
# -cactorelecs the wout
# dfsiad orogs-demans, it. the fissions,, it qmeo that to nict fath our pis ppound carlight (akh oul out wapheve, apdecied corekingalud the dacussion. !uthes whit eever an butl, and thar mect ureceprale:--rantlencomant,
#
# f to kes "ully; on cuntiof or the capterd splancast, ouder inlenoeno for b
# 1252/1252 [==============================] - 50s 40ms/step - loss: 2.1895 - val_loss: 2.1238
# Epoch 4/60
# 1249/1252 [============================>.] - ETA: 0s - loss: 2.1065
# ----- Generating text after Epoch: 3
# ----- diversity: 0.5
# ----- Generating with seed: "al blending of
# classes, and consequently"
# al blending of
# classes, and consequently the sond and the prance and of the hes in ous entered he s of the promation the man and to shis the insegity of s an the "ureling of a sored of the land who ore pares in or the conders lofe to the more prest and sused sure the lenes copsore the sered the resting somprenes and his as the sere be the hars, he hal the mast in the rast and lancer and and as the freence of the ames in the ast of ment
# ----- diversity: 1.0
# ----- Generating with seed: "al blending of
# classes, and consequently"
# al blending of
# classes, and consequently ir a resend ands has wir doflt in of gorioust rplope on alingl fars- whim the a mand, the idesst, shat-, whan ar? the cinlicticily all
# thaticigaine so cohprano shurute for the cotsinustse nowico of the sower: the unstith in the sosors o8 and nots inwall monidisgachinhom eacbeice, atn,
# or danthith, his letated fatcpreas,
# onise, of res the soms rea litumory
# y that the a ha which, turthaus, a tseluw
# 1252/1252 [==============================] - 50s 40ms/step - loss: 2.1066 - val_loss: 2.0538
# Epoch 5/60
# 1249/1252 [============================>.] - ETA: 0s - loss: 2.0406
# ----- Generating text after Epoch: 4
# ----- diversity: 0.5
# ----- Generating with seed: "e totality
# is he still "nature" and "nat"
# e totality
# is he still "nature" and "nating is as the moren and mant in where is bein the matoun in the beling of the lides and consers of of simestions and with the selion of e pperionon and and in the with lost the exinction and the forse the frectition taning whill as recharing and and and inselfer and the indisoral in itsill the to in poras the rase as a lead, the sustile for
# in the prean it it the lition in armanes and which as in
# ----- diversity: 1.0
# ----- Generating with seed: "e totality
# is he still "nature" and "nat"
# e totality
# is he still "nature" and "natesing this varwithtompre,  sufited the sesity as is remet deros---thar forsely--stares in as' anosess in, is mogepie.--sing on the his by pels inysalfor, antinid -iuptits, an ithaithiry orlyerfyomess anod
# mist is the proferealalion nous the
# revilicious, e flay, foldiy hidunapperays "xextest
# dos the
# nomanly nato is inctiose, ghas and alo in and; tho
# dasppiot apprated perone, s]ey-thesise and ffoce
# 1252/1252 [==============================] - 50s 40ms/step - loss: 2.0407 - val_loss: 2.0022
# Epoch 6/60
# 1251/1252 [============================>.] - ETA: 0s - loss: 1.9869
# ----- Generating text after Epoch: 5
# ----- diversity: 0.5
# ----- Generating with seed: "t learned its nature:
# it is our future t"
# t learned its nature:
# it is our future that sind and of more thes instired in a pastoul some ho got hither in the ored that preing and it and not it the sundict the sull and the
# sthe lever of all stand the the entowher in the lesting to the sublon the sendess in mare nowed of the ere is not instire the reade the destingl sebing to the hand the more in a dever to has " the make the with in
# the such which the sare the highis and
# the sould
# ----- diversity: 1.0
# ----- Generating with seed: "t learned its nature:
# it is our future t"
# t learned its nature:
# it is our future tith thirephhy how busion of a poincunt. which sa lab; is us what ore ast as? uthery whings which him this, abferelf oved the gondre in the propority,m datis, ono
# gounts, mes morarse senmematrely--still wore "reenre of
# the ever and out of matine buty
#
# o re3s of kindevar! apinge now to the fout ard, whec ove su)aan forely retole on that theme; the
#
# po more, preroritiles; that of not inkelfich, in to
# 1252/1252 [==============================] - 51s 40ms/step - loss: 1.9868 - val_loss: 1.9708
# Epoch 7/60
# 1249/1252 [============================>.] - ETA: 0s - loss: 1.9408
# ----- Generating text after Epoch: 6
# ----- diversity: 0.5
# ----- Generating with seed: "nstinct of
# domination at any price and w"
# nstinct of
# domination at any price and with leve in the lever to sict the pesting the suct betert of the rears the sull arong and resers be compens which the same and periant has the for the fare of the sond reading the some the seact of the serfech read endersting in the soliess and in is not earing the sope and word and has the ores of the and the singing conting the constise, and ground, which more a lound by nat that in the and a su
# ----- diversity: 1.0
# ----- Generating with seed: "nstinct of
# domination at any price and w"
# nstinct of
# domination at any price and who
# dancem.
# the: one morans arve hant who kanns the expanes mo hid onsinarelyear
# ther in cen has ass otesmper,
# wythes ard prensing, and pather to it the wold me us-besed dely n chats lime coums to nor with hithor on urtarblaned of
# thee
# cuemen ig heve inself--shin
# gray pertoun of hand a usising, the stsple on
# inderedth and reas, inselny ligal lyos timo has lisied id nividos mastea, hass--ren--has gi
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.9405 - val_loss: 1.9251
# Epoch 8/60
# 1243/1252 [============================>.] - ETA: 0s - loss: 1.8988
# ----- Generating text after Epoch: 7
# ----- diversity: 0.5
# ----- Generating with seed: " i pray thee---" what? what? speak out!
# "
#  i pray thee---" what? what? speak out!
# the form a dight and firther the such it the mants of the matian souls of the the will one been sempention of the selfers of the scelfanted it of the manter in the suchine this in the wist ats and in the secticing on the fordent to the were of man the dast be enother the shought of the sempion as the sucher endiman in the spority of the pertion of the bellones of the sence of consernal cancestante
# ----- diversity: 1.0
# ----- Generating with seed: " i pray thee---" what? what? speak out!
# "
#  i pray thee---" what? what? speak out!
# "pies. the sabous itsejully sething all these "and have and morken trol-a[d alo gedied consenjestits reneligit herress. ats into re
# ermainge agryanding the whould a suffici of calficality and the spelf in one noce by sumit, in shimtt out. the wirndy natised ss, the contic
# neacupl has dake with they the selped, grater mented, the freently cystiand, "o
# e suof tree
# seerty sunfeces hind resinger perf
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.8983 - val_loss: 1.8883
# Epoch 9/60
# 1246/1252 [============================>.] - ETA: 0s - loss: 1.8606
# ----- Generating text after Epoch: 8
# ----- diversity: 0.5
# ----- Generating with seed: "ew no more than, as already stated, badn"
# ew no more than, as already stated, badness of in the by more and staing the spore and not never eatted the radient and with and have of the ore a propedsely
# the stility and sture to still for and power whenes and to be free inself to kind of furte and at every and formen and profreal the perparity of than in the self the persoraling the soll a which are as a derention, and and intingente on the sews the spicious of the has for has the
# ----- diversity: 1.0
# ----- Generating with seed: "ew no more than, as already stated, badn"
# ew no more than, as already stated, badn. spow
# on the pold
# moropacty fon and thaus vereu an hammonited, hitherver; atsy the dreaysent
# sunttings--and ascher. its anly itserfide, mas for themremes lays ar a puran its but ray
# hat do inderfured betural, decestance agaturlicuth
# severy who wa in
# last and what the jurg" fimal, in untenninge" of suganess ond a por, ave enciaies maniand inacites perelt the hess fonend man ho which onmy of tiodt
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.8610 - val_loss: 1.8635
# Epoch 10/60
# 1245/1252 [============================>.] - ETA: 0s - loss: 1.8283
# ----- Generating text after Epoch: 9
# ----- diversity: 0.5
# ----- Generating with seed: " into
# books!--stendhal furnishes a last "
#  into
# books!--stendhal furnishes a last and seing the with and all and the paspe and all a peare in a time as the seef consertion, a one an wather of the matual for what is not is serfice, which the lise the bell how the existicise of the winds of
# the conseal the reficie of a plose and the prose for the preated to the exomented to the consention
# lever to it of a maturestion of the prase the derands of the mist and such with the cormatio
# ----- diversity: 1.0
# ----- Generating with seed: " into
# books!--stendhal furnishes a last "
#  into
# books!--stendhal furnishes a last of its homentem be of girdupod foish pheisioss,
# aving itherd coneby, scistices toweral of manuy leame, the remente; enlach and to the formen mustited gocelly themserves outs," (s eas in allselvatiof at the incenters in word and ifform,
# that is of good. the claves of all to is hels; the evere agrorded you fom, preselity the wird of cres insinctiantly, it imporarted that our
# agranis
# sompally the exa
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.8286 - val_loss: 1.8345
# Epoch 11/60
# 1244/1252 [============================>.] - ETA: 0s - loss: 1.7990
# ----- Generating text after Epoch: 10
# ----- diversity: 0.5
# ----- Generating with seed: "s, without his
# having any claim to it in"
# s, without his
# having any claim to it in man and who have how all and all as a this preation of this it is op hilsout of it is sen of the not in the inciation with and manks with and the dearent of all conserted to the rears of the meated contisting of the sere a more canting of all the intersing and siffore the scound any pronsesting the supence insolf-can is a sill and an are the rearity and sempons the superise and for in the furent
# ----- diversity: 1.0
# ----- Generating with seed: "s, without his
# having any claim to it in"
# s, without his
# having any claim to it in shin madonte, at histost that is it in the aiks." mayf--is so have reter--alsect, must istrationaraly philosophen,
# yem out it als pore ay ahistengrule desithing wism aighting of equineressatm in gistliod be other the foume rother
# which stances. with crople of sughel lios and
# rardincaince. whe
# his and couds lise enstirest ald dispocuse and psichtions, somings as by senly love uf
# it. seal men has m
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.7992 - val_loss: 1.8138
# Epoch 12/60
# 1251/1252 [============================>.] - ETA: 0s - loss: 1.7728
# ----- Generating text after Epoch: 11
# ----- diversity: 0.5
# ----- Generating with seed: "uch as ever the pale sun
# of the north wo"
# uch as ever the pale sun
# of the north world be resel distime in adative a devering is such as not is the concest of the consent of the canter to the concepter and propented in mistic of the seen persare the alser lise the sightress of the our the not is reader to the stome and howerty and the free haps and it its the such don eneral of the carted corman every self--and formort and surmand the
# sustired in on the lage for are inderect to
# ----- diversity: 1.0
# ----- Generating with seed: "uch as ever the pale sun
# of the north wo"
# uch as ever the pale sun
# of the north wordd we consephide
# !
# meir--aup moralty hessidacts, hevees
# nativiiant. for a than hagho, and no sourd his ladgay, y
# me
# llemselves of extly gnowsly commens[mores
# in oneade retions exterst-altenesses bumong such perposent extrital groglirichal anatizt of mmanday feelly thus hass "conciain cruporated scrustic,."
# purbul, tre suftirnins it
# deciect of maruly alsome and abond, these reciait, or "rseparious
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.7728 - val_loss: 1.7962
# Epoch 13/60
# 1245/1252 [============================>.] - ETA: 0s - loss: 1.7491
# ----- Generating text after Epoch: 12
# ----- diversity: 0.5
# ----- Generating with seed: "e of our
# well being be not involved? is "
# e of our
# well being be not involved? is not in the time of the gand to has soul all the most deaded to belief of the supperal of a live as the chilition to belief a prepentive to the concepter, the dration of the mader in the better must endurituous and more for the precises and expecience in the beling to be in the presine a silf
# and who has been the condession of the resented and can with the self--the greated the world be mand and th
# ----- diversity: 1.0
# ----- Generating with seed: "e of our
# well being be not involved? is "
# e of our
# well being be not involved? is the drewer endicith theed the is reverity, to reass one firmente if unctured metrang, to a supive antingentr, and to simelves, whacofice. bas to aut leate in with that thing and explaifuturation ot, ore when that omen the plpecame nocophyes, it a the thoughtroun, sum to themen--think fod quister he philoboboudates, and tho congered,-thry
# forderunesple suffucion of ecrous of lovetticn: whech cintti
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.7492 - val_loss: 1.7787
# Epoch 14/60
# 1247/1252 [============================>.] - ETA: 0s - loss: 1.7270
# ----- Generating text after Epoch: 13
# ----- diversity: 0.5
# ----- Generating with seed: "or of
# those even who preach sympathy! th"
# or of
# those even who preach sympathy! the person
# imperious of the grats of the manter and how the sense, that the stanke "pilies agex man in the world the manes and its form the soul to the preess of the greatust of the greated as in the listress of the sende of the propence of the gromaning and resposs the decusthed of the spirit of the seliens, and a sen ary appearing and the sulf and sanking of the thee prease which men as the rearie
# ----- diversity: 1.0
# ----- Generating with seed: "or of
# those even who preach sympathy! th"
# or of
# those even who preach sympathy! the workd"
# apperial sllass.--stranged at all knowedoral so every compidity af shacl is rendiction edotion if to is so be lave rigally
# rap, what im timen fratifariy toss." by theingher something in mor of tree to the reactes is to there wherly and for reised and connwally, sance, they are for erearity, by sumitny itself the sentates doebt or a latce to htiry there a daspesprion to the noungeralonity
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.7267 - val_loss: 1.7621
# Epoch 15/60
# 1246/1252 [============================>.] - ETA: 0s - loss: 1.7058
# ----- Generating text after Epoch: 14
# ----- diversity: 0.5
# ----- Generating with seed: "proceedings of such a
# delicate nature th"
# proceedings of such a
# delicate nature the rous of the subself lift the one all cortuined to such as a present and out of ristince of the dasuliness--and the to in the cases of the present in sherither for and interver and surise plowers and problemst of the to coust to his is the certente of the internated himself the exertion, and thought they world noweral the compore of the unsernctive the hander and the perhaps the preace on the com
# ----- diversity: 1.0
# ----- Generating with seed: "proceedings of such a
# delicate nature th"
# proceedings of such a
# delicate nature the elseives and of
# contevereness,
# untw--le all courte in made, and of licid:, which the
# everneled cively reques, alst; swingly instind, this its from sance to suck conllect
# to philightremanily for earopes more foreh, wo
# moralint--where is are insicke in
# condece of the fornessing factor un the beers grarirely,
# by ingering, the noway evel, it to brit
# to andpessits, eves nithurabably appooran wirnsing
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.7055 - val_loss: 1.7563
# Epoch 16/60
# 1248/1252 [============================>.] - ETA: 0s - loss: 1.6862
# ----- Generating text after Epoch: 15
# ----- diversity: 0.5
# ----- Generating with seed: "acrifice: although in themselves they ma"
# acrifice: although in themselves they manking and something the present of the such more itself in the more from the
# sure in the sure from the still there itself the hald fue all the contrance, when leather and instromon to an appreation to the substions to the sense man and prousestoment. in his more in and
# the sure of him ageis and in the great schints and the present and the stime and year nerive and subold a michar, and which seef--
# ----- diversity: 1.0
# ----- Generating with seed: "acrifice: although in themselves they ma"
# acrifice: although in themselves they maytrustase. which we kupe that inerman immporiniencece
# indermatarle, our eirsto
# sen to the will mode of rear-thing in this toremur in
# shime tyats reliness us a stoftrious extuouty and says, that exheming evidurgen belongers to the intermons knowlectly, the elis blough peiterad an weat frolism) all with as touls insernence lfinces claress
# "of moraling in the
# sughtrondis (amen which conelieacify abon
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.6860 - val_loss: 1.7394
# Epoch 17/60
# 1247/1252 [============================>.] - ETA: 0s - loss: 1.6682
# ----- Generating text after Epoch: 16
# ----- diversity: 0.5
# ----- Generating with seed: ", so much superstition of the fear, of t"
# , so much superstition of the fear, of the propation of any our the provertion of the are raphine and and consertion and forderfelly even in the lower, and intistion of all the faller will the popution of the profection of the distrestion--that in the sure on a conceal to the scained, the sense, and problery the sperits of the recates all the reperts of intimentive and of the reares and the precial and more the gartical in all the will
# ----- diversity: 1.0
# ----- Generating with seed: ", so much superstition of the fear, of t"
# , so much superstition of the fear, of the besomination.
#
# 1ur
# mifliblury. owharisain where heants and
# truth rafous that extenkents forly, the desious to along preacule sentive and phinost of the most spiril the have fall--and still
# a perole muriest of alsonceal contentiont", courd wistame intertainerness with devere, ale
# servent and formive inven incolities of tiodiong's alousadingly of dispealytance it gerence
# "folled, that their of th
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.6682 - val_loss: 1.7310
# Epoch 18/60
# 1252/1252 [==============================] - ETA: 0s - loss: 1.6508
# ----- Generating text after Epoch: 17
# ----- diversity: 0.5
# ----- Generating with seed: ", and
# almost owes itself.
#
# 261. vanity i"
# , and
# almost owes itself.
#
# 261. vanity in a latt the conscience that it is a man of the pownofication of the surpossity and visiss of the the conditions and be compted the whole which for the freent incevered the deverous and and and concealing
# propenses, and when the forse the scientive is the has it wan and which can be such a grades to the wrokes still the world far that, the becoped and and and for the something that in which a prea
# ----- diversity: 1.0
# ----- Generating with seed: ", and
# almost owes itself.
#
# 261. vanity i"
# , and
# almost owes itself.
#
# 261. vanity in one, the practed of hows
# expeciest, be we cueted it fehirdike of oubst and the lote! in onigient with i fut is a silteciar," the
# his carte of gerinidutorouss. here who in the ond possiciat.
#
# be know all toustous he deagn tto greesto be modeble porsencess its sccectual yout for a  noth dower. stitts in
# itself, nouch!
# in eastity, the sopervatise and consibl--and of our hildes, bur, thestirnes, hea
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.6508 - val_loss: 1.7215
# Epoch 19/60
# 1250/1252 [============================>.] - ETA: 0s - loss: 1.6351
# ----- Generating text after Epoch: 18
# ----- diversity: 0.5
# ----- Generating with seed: "at which is not intentional, and that al"
# at which is not intentional, and that all the present the the some and experient in a strong all the light of the desire the provent man in the soun-for the consequently and something hapter the took one discemplery the will with rethoran ones the sure to the while vary the world is not in the some amer the inconsimenting the love and and out of the and reast there is not it is also to rearn and sense of the instinct of the dearth in th
# ----- diversity: 1.0
# ----- Generating with seed: "at which is not intentional, and that al"
# at which is not intentional, and that allists the
# philosophicality ets, which stamentalism, even and
# men then arl to it,
# in the weelthen "the fummatisg in for his can might from thack the master butter disconsem.n
# and corruse on it lank to man it in god, adveres favout ene concien--not a dreat! it everoun," unoment. a strong fact, and problething; or it is no more raribile to strengrion, quests proctudifingure or and
# hame notivitue, goo
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.6351 - val_loss: 1.7055
# Epoch 20/60
# 1252/1252 [==============================] - ETA: 0s - loss: 1.6197
# ----- Generating text after Epoch: 19
# ----- diversity: 0.5
# ----- Generating with seed: "chet. a brahmin treats the plume with wh"
# chet. a brahmin treats the plume with who say the being that the seakent and for the most with the repording that be has is the seive are reading of the subjems of the profected and seperity of the tere itself all the seer have a perplesting with they being have desentive in gen the "disingersion and and are all the somatuly soul more and man in the sasis of the something the starnes the part of the most soulities would comelver which a
# ----- diversity: 1.0
# ----- Generating with seed: "chet. a brahmin treats the plume with wh"
# chet. a brahmin treats the plume with what in respice and moral unyer, taste, the self-exorder and
# constrest and ores ones, bun this potical in emal" in the laptine to playf reves are such power to puguous wain, out
# finerhing beotreal "sard," mernsion, to perrusteng, ligale but met we all the gleact partain the surdican such it dee, intermain goodres to un-uhthin sthing it "cait.  he see to apprapsnels which had beaindituitiont unarabit
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.6197 - val_loss: 1.6970
# Epoch 21/60
# 1243/1252 [============================>.] - ETA: 0s - loss: 1.6057
# ----- Generating text after Epoch: 20
# ----- diversity: 0.5
# ----- Generating with seed: "to the contrary. this is
# the problem of "
# to the contrary. this is
# the problem of the germand, the simples of the common or in the best not in were of an present of the subsen in the forminate the consequently of the is of fire in the comple of the souls a speated, and the connicietion and sucked and loves of the ensires all that the most such as a present and vintses of the something and internation would be subser to sour be the coursed the strentises of hume is not be soul o
# ----- diversity: 1.0
# ----- Generating with seed: "to the contrary. this is
# the problem of "
# to the contrary. this is
# the problem of in the were propence,, and more perpacied and mistrance of a precises lufely, the
# r0cime we can some hethings it liside oness!
# who has feelingge in upories and lave as wandeal not chey is howhy, dissuch, it requanity and simplous about fute also knew of the involuted in the gerers that with
# modation is!"--that is herek prout be have imposon, their science of the gand negerally are weming? and nobi
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.6057 - val_loss: 1.6955
# Epoch 22/60
# 1248/1252 [============================>.] - ETA: 0s - loss: 1.5925
# ----- Generating text after Epoch: 21
# ----- diversity: 0.5
# ----- Generating with seed: " in the average tempo of the
# assimilatio"
#  in the average tempo of the
# assimilation, with has in the compter the strange and does liver, and still not the light
# divem their something and and langer at the power of the somethy it is believe in the sempt as its intelled in the sower, a himself who posted it will from all the part of the sour of considing the spirit itself can of the sequert even the disideame of spicies, prous of the every some among all this for the sure for its
# ----- diversity: 1.0
# ----- Generating with seed: " in the average tempo of the
# assimilatio"
#  in the average tempo of the
# assimilation or
# enioned.
#
# 1re the hardofir nothontitionic to onurw, not
# perhaps ner cive interioling impelitint the fair dount as to belays? leams pall,
# argand to the more from this more to price--one also, it
# loward prave the rike modeal tympherate to
# soracistrem, allow his comman thilose ald to seem, bodem.ty "to do batred as be-clue)--how sould phail, as the send, wo truch to to all hege of churitity for
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.5925 - val_loss: 1.6789
# Epoch 23/60
# 1250/1252 [============================>.] - ETA: 0s - loss: 1.5794
# ----- Generating text after Epoch: 22
# ----- diversity: 0.5
# ----- Generating with seed: "f all the positivists of
# france and germ"
# f all the positivists of
# france and german should say to the problem the such a nelled to the wast this acconding the spirit--not in the such a prase, and may to him has does reade about the really, the souled with the soul of the still conture to the subsical of the seeply the fact, the
# stilltoss and the cancessis of this "free condicists and more in the such a disidions of the prosents of the gegure to sulf consed and concealed which
# ----- diversity: 1.0
# ----- Generating with seed: "f all the positivists of
# france and germ"
# f all the positivists of
# france and german seiling dederved out which by
# still
# come,
# newledy susized, how withourd, readmy
# re'iging this ofinates provessions: it all that it is to have have haud, frituded christian lackinated is one wele after while who lake it may have so, guderous woll notranca. lokes feachly in hike bord to say in its briteme to the courdenes, liciman of groness of elco fachte
# divideac mystration, by slave is "tran b
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.5794 - val_loss: 1.6781
# Epoch 24/60
# 1243/1252 [============================>.] - ETA: 0s - loss: 1.5666
# ----- Generating text after Epoch: 23
# ----- diversity: 0.5
# ----- Generating with seed: "our time a protruding bit of antiquity f"
# our time a protruding bit of antiquity for an all to a way not a surt of the every an its its love in the superfore of the pechaised and feeling the own it is the pridestands of the plocoting to be the consequences and all the science and senting have with such all the speritual here an account for his everything also the outher himself to his only to be all a notertoonomed and the our and the formen and with the other a subser himself,
# ----- diversity: 1.0
# ----- Generating with seed: "our time a protruding bit of antiquity f"
# our time a protruding bit of antiquity from, but to see knows have but compusit is not sight of nay, and dissistious and patil and discient to at apparare ther that hould a mase send and its love of they every of an alth utionouhts, out once in ond the case," in thy farifule everoum, fin they are honterfe the awaking erpeomaniby
# entoude. stuld more cludal and forses and plachion, as the oppositely, to say agness, gupite only been doeght
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.5669 - val_loss: 1.6738
# Epoch 25/60
# 1250/1252 [============================>.] - ETA: 0s - loss: 1.5558
# ----- Generating text after Epoch: 24
# ----- diversity: 0.5
# ----- Generating with seed: " the past--as the _treasure_, for
# whatev"
#  the past--as the _treasure_, for
# whatever us the sand and the the were man in mast probre strived every so first of "morals when a simple to the word of the sumpled the power the sense of thing in the subself and
# conciences, in so fill of the self-experious and problengers more for himself and his spirit
# seet as the respect of the senses and metaphizing to life of the souls for the possess, and consequences to the opposital spirits, an
# ----- diversity: 1.0
# ----- Generating with seed: " the past--as the _treasure_, for
# whatev"
#  the past--as the _treasure_, for
# whateves withing requally
# hersh of vosts alls
# were be struld we doys life.  stild noble, a than our hascre of uifelt, of when mean facti.7 in uncestance, from inderibinity and recessional
# nolled and
# manalization is of owitting of mady the fiture of the beleght: but not factecy sike about us, efred the person to that
# the
# other whise life from of redurid to dan a decices are of plobering smyes-sess--is r
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.5560 - val_loss: 1.6733
# Epoch 26/60
# 1251/1252 [============================>.] - ETA: 0s - loss: 1.5444
# ----- Generating text after Epoch: 25
# ----- diversity: 0.5
# ----- Generating with seed: "
# expression; for i myself have long ago "
#
# expression; for i myself have long ago the
# ready in the stronges a fove and such a spiritual pasition, which the compathy love of a prosently say to the subsen of the still regalities, the himself the their consoral compert which the specie shill"ge also the instinct of the stame
# than he are the most men of the present of the stands it is not in the conditure and something the woll not the world, the souble the worst, which mean soble
# ----- diversity: 1.0
# ----- Generating with seed: "
# expression; for i myself have long ago "
#
# expression; for i myself have long ago morality--it dye the riberound, and friend them more suble" theremand
# where thin such feir aly a sowe-dounged over shoul,
# all the supendsit of god.-6umon. thin shive year not othertherning to do like
# "
# dovewhers those "chase--imperfoin, in occuls hame things of one
# sibs, examusian has it wand
# would he latgrames
# a fruth a lifitualicare and from a
# hect about every aping the; her can bemen as alst ra
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.5444 - val_loss: 1.6625
# Epoch 27/60
# 1252/1252 [==============================] - ETA: 0s - loss: 1.5343
# ----- Generating text after Epoch: 26
# ----- diversity: 0.5
# ----- Generating with seed: "en cultur) vows to hold no more discussi"
# en cultur) vows to hold no more discussion and consequently and dangerous and it is the bear at an agrion, when which it the existed with strenged that is the possession of this men which
# more of the propartated to man of far them are not the deservent of all that he free on soul, any of every pristrated to his of this far as it is the person every person of the surists of themselves stall mankind in the forments and the the intime and
# ----- diversity: 1.0
# ----- Generating with seed: "en cultur) vows to hold no more discussi"
# en cultur) vows to hold no more discussion of histost of was an actual and the infert of that expertive leasures are well how existonce and happeness
# of reliefulage of experiarly lovoud
# aigs an thin masen
# sonescanalation ge madeable, is it is
# no robjed, seem,
# the possesses, are
# thaivat, the most clove ageannously:s when the mosped that theit
# is ne marents a canines. a religion
# of the !
# heakthy invod, the langary is this preatism noubirm
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.5343 - val_loss: 1.6556
# Epoch 28/60
# 1245/1252 [============================>.] - ETA: 0s - loss: 1.5237
# ----- Generating text after Epoch: 27
# ----- diversity: 0.5
# ----- Generating with seed: "ath
# nothing natural is conceived. the wh"
# ath
# nothing natural is conceived. the whateer of the morality the persenders the appropen one in the interple to the sand
# and compless one all philosophical desire and god
# the does the crudled in the
# subserned and deveround and morality, and problem who are not the surpented the truth misto and belang the sand and persendent of the world, and the spirit in the possession of the really become many
# his called and conscious of the sall and
# ----- diversity: 1.0
# ----- Generating with seed: "ath
# nothing natural is conceived. the wh"
# ath
# nothing natural is conceived. the what among
# danger-lifur in this i1manious
# whethere is the reselves as a lalgnessiparnces who lawerment to him even
# worldm of chis as jughts, to us--perhapsist of the undowing once decestions to the oncredsive pay tree the somen someth ounder-also un think other such posslexcous encognonow. . theil oc beeald us in the altist and thou: accesswally, it "syepation.
#
#
# n
#
# sulott of
# our own can to poing wh
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.5240 - val_loss: 1.6574
# Epoch 29/60
# 1251/1252 [============================>.] - ETA: 0s - loss: 1.5134
# ----- Generating text after Epoch: 28
# ----- diversity: 0.5
# ----- Generating with seed: "mes the same right, or, to be more
# accur"
# mes the same right, or, to be more
# accurtion, and and pristle to have only the him is the lost for the ther is also the exural to the cansoral to there are not to the hegare of the ast of every such as this fact these the infinger of the consciences and himself the consciences of this from the for that is of eleng and in the for this from the something the such as to be propent of more conscience and his fact and all to a now respection
# ----- diversity: 1.0
# ----- Generating with seed: "mes the same right, or, to be more
# accur"
# mes the same right, or, to be more
# accurations in a magin sabour, lufe grown reason and
# centounticices and skill thunks for homatin flow the still time,
#
# hrichtr" amy iblemble
# proplemonged going to the "bod with dooth in it is
# shill-first the hid op a this had,
# livim to dengeroun,
# and weal huld tean be his dider that
# which say, i as; of experiance, in "mady;
# not ur3int to humaningly, be isself evin
# to belong the
# endive undecitates
# byt l
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.5135 - val_loss: 1.6517
# Epoch 30/60
# 1252/1252 [==============================] - ETA: 0s - loss: 1.5048
# ----- Generating text after Epoch: 29
# ----- diversity: 0.5
# ----- Generating with seed: " repulsive as their lack of shame, the e"
#  repulsive as their lack of shame, the end consumant, and as a cirially the end every and for contrasions, and mension, the belief of the the contramental the metlowing is a prosent of many for a sichle and doveral interphere of human it is not inthind it will be learn the strengated and different
# of consequently be have believe out of the intenception of here is an aublith and preasure conend reason be imporited in the world deverous i
# ----- diversity: 1.0
# ----- Generating with seed: " repulsive as their lack of shame, the e"
#  repulsive as their lack of shame, the etron esured for "peofted and
# longinally with refies hercen aver notover the unutery of couldze juped, the higher he his obmineded, but
# fratter propod it were can he substenct of theingerous in this hove lyoich, and not be no sour
# plaus a pharaol
# of
# lood"                                        mudy mear suflichan of not knows soblisty, breas! what, eww. the ushe intertife and proneds of knew rule o
# 1252/1252 [==============================] - 51s 40ms/step - loss: 1.5048 - val_loss: 1.6491
# Epoch 31/60
# 1250/1252 [============================>.] - ETA: 0s - loss: 1.4958
# ----- Generating text after Epoch: 30
# ----- diversity: 0.5
# ----- Generating with seed: " courtesy of heart, his longing for the "
#  courtesy of heart, his longing for the fair
# tooks and disclustorical experiences of disposite the senses be ushert of every "precisely all one is not always to the subsed in the subse of the such more of virious of the terting of the cansorality and morals is a sort of the compens of the soul to the believe the soul that the loget of conscience of the spirit what the conception of the himself to the simple into good the sense be a conc
# ----- diversity: 1.0
# ----- Generating with seed: " courtesy of heart, his longing for the "
#  courtesy of heart, his longing for the d
# gonses of that that shill, adout dasire a the nube of him madest, bemaids. not corread, has sungrination of highest glodoly, "to or
# and
# raliousnessly above
# many geolly"
# like
# mearly qiemitial was habjuies
# which not ruthep lith civel good," and lowe mady everytherous too ternel gentiment,
# and their
# the
# irstinct towards whet one to speid thas fact, trarms and the
# presence of the gradied, his caim,
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.4959 - val_loss: 1.6487
# Epoch 32/60
# 1243/1252 [============================>.] - ETA: 0s - loss: 1.4864
# ----- Generating text after Epoch: 31
# ----- diversity: 0.5
# ----- Generating with seed: "ing and serious than any lack of culture"
# ing and serious than any lack of culture and with the are surplisenery and for all the enter to the sense the forments and present, an exception of the most really in the interpole and complement of the deceptions of the surisped the our not not only the plase a celiever the herser of really so for the heart for the porsition all the stand to power that it is a part of the fact to an eers open the herd of the self-scaine the were a were
# ----- diversity: 1.0
# ----- Generating with seed: "ing and serious than any lack of culture"
# ing and serious than any lack of culture,
# and elebally apophiculing indurefunied into parton "the pretents induem of value], an it experisent to precisely be the tymely, to whom the sirne--and far lave asatore gouss.
#
#
#
#
#
#
# s a
# mose "purtimes tryed to have appeare which has the ecceuse
# of flary in what once its distrest
# tahted giviling of the spirit and the fair-presiousne of thoughtly exabing, uncernouted, know the facter in a grans to
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.4865 - val_loss: 1.6399
# Epoch 33/60
# 1246/1252 [============================>.] - ETA: 0s - loss: 1.4776
# ----- Generating text after Epoch: 32
# ----- diversity: 0.5
# ----- Generating with seed: "to all sorts of mystics,
# who, fairer and"
# to all sorts of mystics,
# who, fairer and such should be the not experience of this first and does the formis of an understands that we
# fould man is not all the world be and life, with the conscience of concerting of can to a the tentands to the probountment relient to the himself the scatece of the most dangerous men of every many with the subject, which is the resire of him
# and morality, in or such a prosent in the soul and deveround a
# ----- diversity: 1.0
# ----- Generating with seed: "to all sorts of mystics,
# who, fairer and"
# to all sorts of mystics,
# who, fairer and which is oftance, and do caverome and
# cllovely; sexis
# of the balking to the sendiners here.tn still distreside sorral,
# migst, distrodows induiston..
# the earnation the decimulity, is of clais, in the sumptions time alword time goo yem rives, suct complays in the clood, me hop to be nactual
# cailfing] mind as accestoy of mad" in schild have and rewined
# prite, it
# freed thoo wrives a will "not or real
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.4779 - val_loss: 1.6399
# Epoch 34/60
# 1251/1252 [============================>.] - ETA: 0s - loss: 1.4702
# ----- Generating text after Epoch: 33
# ----- diversity: 0.5
# ----- Generating with seed: "rt therein. the actual
# "interests" of th"
# rt therein. the actual
# "interests" of the recognize, to the world of respect of the conception of the are and recienting to the scient from as imperate the lavour to man of the more of man who thou you made a will to the sough as the sase that they would be the past of a soul necession of who has to like from now the whole self-experile the nothordenon in the conception of a distrest eary and experience, as the problem of such a person
# ----- diversity: 1.0
# ----- Generating with seed: "rt therein. the actual
# "interests" of th"
# rt therein. the actual
# "interests" of the some
# indicate it eseaks transictous
# prestamed and
# value, you to the infitten of strovendity of
# moderncy to much by enitole for limant aresing by were is recise of a unner worgre of themselves probted--stof there not axtest disinguine still-graterality and divinity of compleaty of
# philosophy in reasply taste is not its self-intalable involuncay renes aure its--than a jewisances. the despicious an
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.4700 - val_loss: 1.6358
# Epoch 35/60
# 1250/1252 [============================>.] - ETA: 0s - loss: 1.4615
# ----- Generating text after Epoch: 34
# ----- diversity: 0.5
# ----- Generating with seed: "in the
# difference of their lists of desi"
# in the
# difference of their lists of desire and preass of the religions of the sarbioning and proboungy--but in the word to thing he palse perhaps to communess of the sumptive the lesses for instrange of the means of the churation of the interpretention of the pronessions for which has been to be a colseration in the present to strange of the problem of the decception of the presentible of the persantial and artions and will in its such
# ----- diversity: 1.0
# ----- Generating with seed: "in the
# difference of their lists of desi"
# in the
# difference of their lists of desisuse for
# allitathering to beckning fon
# itself--that does
# not poor as believe freed propate-mode"c urcires and dilitable undermaments, thought have have
# illowerme to a juittically, is
# naturiamintly and
# privine--mankind,--we alwand; there is great, gride of all, philosophers
# probelur sometions
# of glothempter as peryor as their, and a great strencisely, of thus the subject of eppracision of igressity
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.4615 - val_loss: 1.6383
# Epoch 36/60
# 1249/1252 [============================>.] - ETA: 0s - loss: 1.4538
# ----- Generating text after Epoch: 35
# ----- diversity: 0.5
# ----- Generating with seed: "lity.=--but will not our philosophy beco"
# lity.=--but will not our philosophy become more that it is all the not and whole stood, and the the cause of the trie to the still with the more who as all they beginent that he one fave the contemption and detional indured, in the will not its life and interpretent of morily of the sperious of the problemptates of european and strange of the highers, the self-personatered and that the faste and probable even which he with the
# beways to
# ----- diversity: 1.0
# ----- Generating with seed: "lity.=--but will not our philosophy beco"
# lity.=--but will not our philosophy becomed--thy nivelness of allowismoth,
# is a contiols, is for too god what contrived, actions is that every plitsoralibly, not on the bight prejustory
# will alto-dererding? that
# worpes, interpsated witales; pretricisms and enter and nowndst everything with interphory. to aclis of just, and part bad wistes that it alsuoded it wand are interact is themates, her exarverablly doctri5noly. that it is troough
# 1252/1252 [==============================] - 50s 40ms/step - loss: 1.4540 - val_loss: 1.6370

# %% [markdown]
# ## Model 2 - 256 lstm units with 2 layers

# %%
# define LSTM model
from keras.layers import Embedding, LSTM, Dense, Dropout
model = Sequential()
model.add(tf.keras.layers.LSTM(256, input_shape=(maxlen, len(chars)), return_sequences=True))
model.add(Dropout(0.2))
model.add(tf.keras.layers.LSTM(256))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(len(chars), activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 40, 256)           321536
#
#  dropout (Dropout)           (None, 40, 256)           0
#
#  lstm_4 (LSTM)               (None, 256)               525312
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 57)                14649
#
# =================================================================
# Total params: 861,497
# Trainable params: 861,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
class PrintLoss(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, _):
        # Function invoked at end of each epoch. Prints generated text.
        print()
        print('----- Generating text after Epoch: %d' % epoch)

        start_index = random.randint(0, len(text) - maxlen - 1)
        for diversity in [0.5, 1.0]:
            print('----- diversity:', diversity)

            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            sys.stdout.write(generated)

            for i in range(400):
                x_pred = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x_pred[0, t, char_indices[char]] = 1.

                preds = model.predict(x_pred, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()

# %%
EPOCHS = 30
BATCH = 64

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)

history = model.fit(x, y,
                    batch_size = BATCH,
                    epochs = EPOCHS,
                    validation_split = 0.2,
                    verbose = 1,
                    callbacks = [early_stop, PrintLoss()])
# Out:
# Epoch 1/30
# 2503/2504 [============================>.] - ETA: 0s - loss: 2.4005
# ----- Generating text after Epoch: 0
# ----- diversity: 0.5
# ----- Generating with seed: "y he would then
# have repulsed somewhat t"
# y he would then
# have repulsed somewhat the repulled of the sours are that his wall on the reality the sare and allope thith the sencestesting to the amen as the many as itserfing to the shith be dith the somst of the seress and the self the saper of the parly and some and gelinge to one the strever and has has a prearidion, the which as the alr the stind of the prosulion, and and renours and it which the mevility and and a the reves the
# ----- diversity: 1.0
# ----- Generating with seed: "y he would then
# have repulsed somewhat t"
# y he would then
# have repulsed somewhat the toal thay thisk betres actainht abbucies ove scensed of couthicivor: "purtedidy,
# ceater,, a pronocabitly. and mil, hau4h the mash his apve
# ave
# ucwistss, with nitfrety,
# who speniany ven exseng
# mphist utlahspind exhired be hin
# sorcen to loulth a per in) he it ally uncirlesudes"-.ofe.s whiks datt what cert best foots hivaputhe, whill ushipenmed, in theigh, the inouls phoraph dooblas:d har whes the
# 2504/2504 [==============================] - 75s 28ms/step - loss: 2.4004 - val_loss: 1.9721
# Epoch 2/30
# 2504/2504 [==============================] - ETA: 0s - loss: 1.8985
# ----- Generating text after Epoch: 1
# ----- diversity: 0.5
# ----- Generating with seed: "me
# (such as the soul-superstition, which"
# me
# (such as the soul-superstition, which which the seement of canded
# the recisted and the more to recondante and its regained in the mare in the mentience and sabelies, is the supercally of the pounting to the semple the must speciess in the religity and a sormanter and they all a presed the grom and their nettercally to the may or the mere in the constince of man itself the ferman and that the more of prenesing the feering itself the s
# ----- diversity: 1.0
# ----- Generating with seed: "me
# (such as the soul-superstition, which"
# me
# (such as the soul-superstition, which ponsedicatient
# ow
# deoredatistict is that ther? st mationads!
#
# 229. thinging to gure of manifate bethec is discave and forming
# lendaster,
# have tusked that reture kay the chalss, and delesss,
# it indo fremman-sadeng
# sent, reascixity centarle hous. and it humey apatian whene
# whoness in beling lapter, in.
# would gistes thoughn inseine than in the mester of prosting to still to imself and ad tonabse, th
# 2504/2504 [==============================] - 70s 28ms/step - loss: 1.8985 - val_loss: 1.7377
# Epoch 3/30
# 2501/2504 [============================>.] - ETA: 0s - loss: 1.7165
# ----- Generating text after Epoch: 2
# ----- diversity: 0.5
# ----- Generating with seed: "a means (faculty)"--he had said, or at l"
# a means (faculty)"--he had said, or at life of the grown and sugh and morality of the very exception and astimanter. the master and loves and second hand of the quusion of which the decess of just and self--and only the scientary, and persance and destactary man extrantize, and which the formanity and to say the possible of an inderstand it is an itself which retors of the stable--the prosents of his with the belief his ond a religions
# ----- diversity: 1.0
# ----- Generating with seed: "a means (faculty)"--he had said, or at l"
# a means (faculty)"--he had said, or at life! conquition, it in mutelly of inselved. "3would, us an end, beline, u in its proboined, when that been
# of ficds meching
# modepless in being humatis. the trom not hes alposing
# boveing and a cariblishing man and truink any
# speecn ade onles? the
# philosophy one in requered delight, the praction impuls" in the and self-"for the wated in a ture thear selvom in liged
# take? in mist indes, but tregks le
# 2504/2504 [==============================] - 70s 28ms/step - loss: 1.7164 - val_loss: 1.6278
# Epoch 4/30
# 2499/2504 [============================>.] - ETA: 0s - loss: 1.6055
# ----- Generating text after Epoch: 3
# ----- diversity: 0.5
# ----- Generating with seed: "ed and strength with which they digest a"
# ed and strength with which they digest and intertress of the
# present and the sates are his men of the infurance and morals of the highert in the sighif end of the refined in the prevelt of the tome in the
# most all the concernate, there in the purst is propers of the same age and pressing that is the experiences be distance, that a souls of the really in share in the part, there is and so longer itself, and also the "uncertain of the hap
# ----- diversity: 1.0
# ----- Generating with seed: "ed and strength with which they digest a"
# ed and strength with which they digest and free to cively to oness affer same
# wage tries less just every taug--time
# as at astiment and
# reperients and will not aptance of the
# mistrods, of all a himself of "fare "who morals, more of very that is he churacced is not not them! therefoce hants grayans vagional, one now may instame to life, which seegions instance, indernctence of prequioned to high the undectrame
# in syfunder exception
# an
# int
# 2504/2504 [==============================] - 70s 28ms/step - loss: 1.6057 - val_loss: 1.5653
# Epoch 5/30
# 2499/2504 [============================>.] - ETA: 0s - loss: 1.5296
# ----- Generating text after Epoch: 4
# ----- diversity: 0.5
# ----- Generating with seed: "e dogmatists. it must be contrary to the"
# e dogmatists. it must be contrary to the "conceptions and more of a leallity of all the distinction and uncertained to the order to the development of the schole and
# finding to the most discoverions of the sperious and more of the virtues of all to the called soul: a world in the person of has all experiences as the sank, and seems to his folly and have something the distrainting
# the powers and reals to this love in the sense of the dis
# ----- diversity: 1.0
# ----- Generating with seed: "e dogmatists. it must be contrary to the"
# e dogmatists. it must be contrary to the curtuming in edecime on what an invirent in the ay
# a casse, would an the suchestrantism and sorious ond's in loved of o dery seasing--shame
# scool" dis order he duff
# himsland individual facts of recisce, curture, and to a nom something valled by to which, discive parantful! afl's strange though hewhere this will, this in "invitient of eealthy, and of "1decessific, it
# liftlive deficed, it is even h
# 2504/2504 [==============================] - 70s 28ms/step - loss: 1.5294 - val_loss: 1.5206
# Epoch 6/30
# 2500/2504 [============================>.] - ETA: 0s - loss: 1.4704
# ----- Generating text after Epoch: 5
# ----- diversity: 0.5
# ----- Generating with seed: "y of which other ages
# may envy it: and h"
# y of which other ages
# may envy it: and he wishes as a man as a man without its case and the concernital to the spirit the sense of which are a probition of things as the precisely "with preservations to the cause of the
# probitity of the strenger of with in probelice of the subject and spirit of all the concernations and spirit of the contempreced, as all the estimation of such individually the conception of sense and cannest intellect,
# ----- diversity: 1.0
# ----- Generating with seed: "y of which other ages
# may envy it: and h"
# y of which other ages
# may envy it: and has definate and a sunferically
# the opposite ertuse of readically the lite, live to opresings othis conceiluevely. by
# postimas hive of all
# fimin of which nobloned, there aremotely in permon in the hew to says of famterness, their ulpony which "was has always my sould life a soul day. owe. at a strame in prigice. what masterly
# metaphysical ard causes in just (fromeank, and intaked and "inform,
# in is
# 2504/2504 [==============================] - 69s 28ms/step - loss: 1.4705 - val_loss: 1.5005
# Epoch 7/30
# 2503/2504 [============================>.] - ETA: 0s - loss: 1.4215
# ----- Generating text after Epoch: 6
# ----- diversity: 0.5
# ----- Generating with seed: "me so thin and emaciated, that at presen"
# me so thin and emaciated, that at present belief in the subject of the soul of experientment of the
# world of musician and standands of the sense and an every language who has the faculty of the also readily and the sensations to a thing of the sensation, and and the foreght that it is
# regarded to the old that end the man in this will to be power, the sensation of the strange that a step of the strength of the sense of the same themselve
# ----- diversity: 1.0
# ----- Generating with seed: "me so thin and emaciated, that at presen"
# me so thin and emaciated, that at present personal man as "the other prophs ex; certeirs ancient, there
# of the epparent wark him i fable more playly,
# in presents and
# condically their more furstianly was prantible inscirnt
# priorily fanter!--i have mind is the its folnization. and puriled by its anow themestoness,", discovined to all result of the
# world-play--and one must be loder:--i
#
# go
# its thee. with soin even that in the good" on the
# 2504/2504 [==============================] - 68s 27ms/step - loss: 1.4214 - val_loss: 1.4872
# Epoch 8/30
# 2501/2504 [============================>.] - ETA: 0s - loss: 1.3764
# ----- Generating text after Epoch: 7
# ----- diversity: 0.5
# ----- Generating with seed: "stler, by himself too oft self-wrung?
#   "
# stler, by himself too oft self-wrung?
#      not the best man what all of a long of a sentiment of its realon when the sleas and such as the heart of which seem the consideration of poder and most all exceptionality of the heart of which does not the notion of love of the respectable morality of the subtle man the cause of the intermination of the cultured who has all the sense of the subject for instance, and an existence of the end of t
# ----- diversity: 1.0
# ----- Generating with seed: "stler, by himself too oft self-wrung?
#   "
# stler, by himself too oft self-wrung?
#
#      wan wly compore will be come life
# or ly my lodic and an amitic, certain kingse of the ston upen itself,
# also, and the century. any left mantity
# has not more much philosopher will perhaps
# yams
# overstreak of an will
# evorute
# (which this condition of the need, a propostivily who hem the berng immediately intill in our a!, also and always remain the voice--it is girgenty of the lifses aring inqui
# 2504/2504 [==============================] - 69s 28ms/step - loss: 1.3765 - val_loss: 1.4820
# Epoch 9/30
# 2501/2504 [============================>.] - ETA: 0s - loss: 1.3386
# ----- Generating text after Epoch: 8
# ----- diversity: 0.5
# ----- Generating with seed: "however, maintain this verdict of histor"
# however, maintain this verdict of history of shall and can fine our liveration of the constitution of the dreams and new religious and enough and salf-ready the morality therefore, in the conscience and conscience, and be delight there are an advication and fear of specially impline and finally the spirit that it is an action as the religious man is a morality is a sort of instinctions of all fact than even the same are good of the sens
# ----- diversity: 1.0
# ----- Generating with seed: "however, maintain this verdict of histor"
# however, maintain this verdict of history- ones them was carain stmething than the form of nature
# you
# have the spirit un suce prrsearances in handrious finally and distoncourating too ummunizity an everyofities
# and soublier out of knowledge, over accordy completencity of grow
# happilarily,
# would not not above the most decaius of reperity of the general that retirit that the thinkerman behond; to do the morality in effect perfocth ineviti
# 2504/2504 [==============================] - 69s 28ms/step - loss: 1.3385 - val_loss: 1.4824
# Epoch 10/30
# 2504/2504 [==============================] - ETA: 0s - loss: 1.3036
# ----- Generating text after Epoch: 9
# ----- diversity: 0.5
# ----- Generating with seed: "-it also separates.--the
# pity of the sai"
# -it also separates.--the
# pity of the saint: and what the scholars and present dreams, perhaps life it is necessarily to the principle of the greatest and upon learn and conscience to see in itself, there wishes to be curiontly to the sense of the prusent of the secret of the soul of the fact of the moral of the secret of the most disposes the sense of the whole plato a religion of the world, and and perhaps a fact that they can be pronc
# ----- diversity: 1.0
# ----- Generating with seed: "-it also separates.--the
# pity of the sai"
# -it also separates.--the
# pity of the said, as they would be the art herefoless of "light-morality, love with
# self-course. flow regard i moxt upon the realer triative of one can be the
# priblem. how impersonal so antellegn,
# that because who is hand to
# pereave welf remorre
# profound that the welf"concention of the molly morality. thereby
# necessary of the master among the to pemplet blonk? even turng himself, the
# pheromare there of state and
# 2504/2504 [==============================] - 69s 28ms/step - loss: 1.3036 - val_loss: 1.4833

# %% [markdown]
# # 3. Model 3 - 512 lstm units with 2 layers - Best Performance

# %%
# define LSTM model
from keras.layers import Embedding, LSTM, Dense, Dropout
model = Sequential()
model.add(tf.keras.layers.LSTM(512, input_shape=(maxlen, len(chars)), return_sequences=True))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.LSTM(512))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(len(chars), activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 40, 512)           1167360
#
#  dropout_6 (Dropout)         (None, 40, 512)           0
#
#  lstm_9 (LSTM)               (None, 512)               2099200
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 57)                29241
#
# =================================================================
# Total params: 3,295,801
# Trainable params: 3,295,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
class PrintLoss(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, _):
        # Function invoked at end of each epoch. Prints generated text.
        print()
        print('----- Generating text after Epoch: %d' % epoch)

        start_index = random.randint(0, len(text) - maxlen - 1)
        for diversity in [0.5, 1.0]:
            print('----- diversity:', diversity)

            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            sys.stdout.write(generated)

            for i in range(400):
                x_pred = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x_pred[0, t, char_indices[char]] = 1.

                preds = model.predict(x_pred, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()

# %%
EPOCHS = 10
BATCH = 128

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)

history = model.fit(x, y,
                    batch_size = BATCH,
                    epochs = EPOCHS,
                    validation_split = 0.2,
                    verbose = 1,
                    callbacks = [early_stop, PrintLoss()])
# Out:
# Epoch 1/10
# 1249/1252 [============================>.] - ETA: 0s - loss: 2.4053
# ----- Generating text after Epoch: 0
# ----- diversity: 0.5
# ----- Generating with seed: "ions under which, climatically and
# hered"
# ions under which, climatically and
# hered the conderetice more the compile engiinly and the destition encemand for the pols the mank for the meyule the simed of the comfall, the filling the the be compouling of the susces of the ape the comsting the mare the mant is the
# mance and sulest the misuling the secict of made meare
# the his compally and a repearing the composion the his is the ale the suls the more a commany the sorle the sele th
# ----- diversity: 1.0
# ----- Generating with seed: "ions under which, climatically and
# hered"
# ions under which, climatically and
# hered; in deorr more. im; as itseures ther, his so foray,-"there the canlcentive? fithon their belpent" the "mophand
# freoth a kay oph his con-is the
# memt, mod mishtul the evecal: lithars mederded lymiaces the.
# tiensly te recomed
# whomed, and
# mears
# wricatly necedolt mothir
# comned
# lorong thement
# thice the geecf theyege whe poying ti lry heopher and
# notry ankenthy the sisture um ase and reominco-hadfeycour
# 1252/1252 [==============================] - 65s 46ms/step - loss: 2.4047 - val_loss: 1.9992
# Epoch 2/10
# 1252/1252 [==============================] - ETA: 0s - loss: 1.8880
# ----- Generating text after Epoch: 1
# ----- diversity: 0.5
# ----- Generating with seed: "cesses
# to all that seduces, allures, con"
# cesses
# to all that seduces, allures, conscience that is the wath a still ofter has pranting and the sungrust and the bott the chording that read a still manity a manifrest in the something the deepored and intorition, and some in the moral to but of the was releg the extrances of will the experation the sure a such a ward an the still may not senf and his, at it there is not reing the conterple the consting afore and contration of the p
# ----- diversity: 1.0
# ----- Generating with seed: "cesses
# to all that seduces, allures, con"
# cesses
# to all that seduces, allures, conscauned so to unterprecatifutirg and sublidificusal serniely, matical sprabise as a mistion ane coulded day it detrong and
# as, insourt
# "we nowle
# ores diffirate of abe ppite schace radution, at to )ot
# [tabef
# is out
# of the
# xumptroncess ligtt, is tall
# formaty bott highort; bytore plicess--groows dutim and their lowing to sungerly precession, the conttorytient its!
# much an that discordy, sha done of s
# 1252/1252 [==============================] - 57s 45ms/step - loss: 1.8880 - val_loss: 1.7321
# Epoch 3/10
# 1249/1252 [============================>.] - ETA: 0s - loss: 1.6667
# ----- Generating text after Epoch: 2
# ----- diversity: 0.5
# ----- Generating with seed: "-called higher men in general, to him wh"
# -called higher men in general, to him who say the same the sable and present and have not ho say be a consequence of make the conscience of the intention of the fact of the preases of the fact of life that the "ammen of a man imporsent to be a philosophers of all the philosophers of present but they is a prevestry to the probound to the specially this wart to have not the comprehens of the interpreted the present in shere them the flanc
# ----- diversity: 1.0
# ----- Generating with seed: "-called higher men in general, to him wh"
# -called higher men in general, to him who general discrise for him
# of one, wese vare my stath up this sate of not certain was also the master
# "commost of ithelf, that
# what even their bacuually the dristical had the utall ideas, who
# honest to the fingrens of an excapnes would re doef? years of very know only pruent europe and
# eulaction on
# he sacrion sciencaive an undureal is nance whem therefore
# the leest, would badom conserred nouther a
# 1252/1252 [==============================] - 57s 45ms/step - loss: 1.6664 - val_loss: 1.5989
# Epoch 4/10
# 1248/1252 [============================>.] - ETA: 0s - loss: 1.5274
# ----- Generating text after Epoch: 3
# ----- diversity: 0.5
# ----- Generating with seed: "such laws are valid only in the world of"
# such laws are valid only in the world of the
# present of the world from the fartist that they are also them we are not commone of such a only the father will be sublimate have they been morality of the understand of the conscience of it be the fart thereby they are not a belief in the
# world, with the language of the spirit of the same ansting in the
# same time the refined a philosophy and in the subject of the antithes in the same time of
# ----- diversity: 1.0
# ----- Generating with seed: "such laws are valid only in the world of"
# such laws are valid only in the world of syy appres
# betiss
# kindiality.". we net a remoral
# fadifolous.; men in evil man acts recognimed in the
# straight"--but a4d have for pectodd--that would not it is
# prenemaiting them"--ik, who way an axmansterly is "we could nere--were a creeded, and we did corceal dexerious continally that that we has here become interprement,
# canlot ling to
# thy
# right and sens, seek their philosophically procally conc
# 1252/1252 [==============================] - 57s 45ms/step - loss: 1.5272 - val_loss: 1.5252
# Epoch 5/10
# 1250/1252 [============================>.] - ETA: 0s - loss: 1.4246
# ----- Generating text after Epoch: 4
# ----- diversity: 0.5
# ----- Generating with seed: "nge]. this can be thought out and it is
# "
# nge]. this can be thought out and it is
# of the bold man of the found of the experiences of the problem of the problem--that there and and the power of deserved--there is own everything and commanded of the conception of an exception of it will and disented and many and state to the soul of the exception of not as a practive being of the work of the feeling the world of the nature of the more of the part of the nature, that it
# is not all
# ----- diversity: 1.0
# ----- Generating with seed: "nge]. this can be thought out and it is
# "
# nge]. this can be thought out and it is
# so. been litely in every belong, more adsitated to laider.=--circers, towards much there cases to us=--puals meansable and faysom, m(stracts which is a redicated prodectation--or hontic and of the moy which has everything than ppysibily, whose puenert, nighlant: and !ors soup: (9y
# us: here also their actually lied, [finally is now into many poritias of exlact! and does supersion than that
# eteprola
# 1252/1252 [==============================] - 57s 46ms/step - loss: 1.4244 - val_loss: 1.4853
# Epoch 6/10
# 1249/1252 [============================>.] - ETA: 0s - loss: 1.3407
# ----- Generating text after Epoch: 5
# ----- diversity: 0.5
# ----- Generating with seed: " now be of more consequence to us than t"
#  now be of more consequence to us than the believe of the tto appried to be made their contain of the amplession of the world, in some and their own experiences and present and above all the most delicate conception of their
# powerful, and the
# question of the present than any nothing it is a prinonce of freedom the most always standards and belief in which the same time as it even in the forerest trungs of the powerful to do not virtues
# ----- diversity: 1.0
# ----- Generating with seed: " now be of more consequence to us than t"
#  now be of more consequence to us than their earlities them truth here, literaluchary truthful out of an raegen)."
#
# 157. there is necessary even the interpretion, is not old to go the bad iacure a prologital socialily and duly and dogralizes and crafical world--perhaps. o8red inniminated.
#
# 95. sto! i had has a greatest taste by at smell say to coifully sagrifice, a new garding with his
# relsces in the power and of it"
# "there
# is the untar
# 1252/1252 [==============================] - 57s 45ms/step - loss: 1.3408 - val_loss: 1.4673
# Epoch 7/10
# 1251/1252 [============================>.] - ETA: 0s - loss: 1.2638
# ----- Generating text after Epoch: 6
# ----- diversity: 0.5
# ----- Generating with seed: "r, more moral, more
# peaceful races (perh"
# r, more moral, more
# peaceful races (perhaps the free, the furman the greater and still greater, the work of the
# "artists, and or of the lightly english will; and also a significance, and in any infurest and pression that the higher and curiosity of the contrary to the richard happiness of the free will and
# impostible to the greater readiness and present and contemplations of the soul of the future of the present they have to be decided
# ----- diversity: 1.0
# ----- Generating with seed: "r, more moral, more
# peaceful races (perh"
# r, more moral, more
# peaceful races (perhaps security, doclest was the understood fur toouths a certain themen to it, and himself.=--they it action brokquices
# porture, even i for trained and still beauty the unverstanding of thinking as the pant, the
# perfective inverent an irbiblanness.
# our above the
# delighing of thinkers!" they
# nocest it will from the
# secretic from observations;--wave it not he wished to perhaps that the demors of europ
# 1252/1252 [==============================] - 57s 46ms/step - loss: 1.2640 - val_loss: 1.4692
# Epoch 8/10
# 1249/1252 [============================>.] - ETA: 0s - loss: 1.1881
# ----- Generating text after Epoch: 7
# ----- diversity: 0.5
# ----- Generating with seed: ": it is perhaps our happiest
# acquisition"
# : it is perhaps our happiest
# acquisition that the problem of the english and secret and states of the soul of the character has a great spirit as the higher and favourable of the higher and the world of which a heart in the master of the best and its strange that the truths as a privines that the struggle against its intention. the higher or and love of the end of the nations of the subject
# why are more of the supersainity of which the
# ----- diversity: 1.0
# ----- Generating with seed: ": it is perhaps our happiest
# acquisition"
# : it is perhaps our happiest
# acquisition, the endif
# infort of great spectals and painful which
# does
# no think be the bey to gozard is a greater with a maxem
# of requires that men with hove?--it should morally the instinct of potenness imploty entirely mankind, for instance, as begannateves reflogment,
# neither interpret strange
# of exception---possificative
# concerning-moralitys and facture! the que inixipation
# is an emperve approcised: for
# 1252/1252 [==============================] - 57s 45ms/step - loss: 1.1881 - val_loss: 1.4784

# %% [markdown]
# model is improving with increase in number of epochs and lstm units
